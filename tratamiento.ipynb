# %%
#Imports y carga del dataset
import pandas as pd
import math
import io

pd.set_option("display.max_rows", None)

with open("movies_dataset/movies_metadata.csv", "r") as f:
    df_raw = pd.read_csv(f)

# %%
#Excluir columnas que no vamos a usar
exclude = ["homepage", "imdb_id", "original_title", "poster_path", "status", "video", "id"] 
df = df_raw.loc[:, df_raw.columns.difference(exclude)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7e2193625b4c> in <module>
#       1 #Excluir columnas que no vamos a usar
#       2 exclude = ["homepage", "imdb_id", "original_title", "poster_path", "status", "video", "id"]
# ----> 3 df = df_raw.loc[:, df_raw.columns.difference(exclude)]
#
# NameError: name 'df_raw' is not defined

# %%
#Comprobación de valores nulos
print(pd.isnull(df).any())
print()
print("Filas totales:", len(df))
print("Filas con algún valor nulo:", len([x for x in df.isnull().any(axis=1) if x]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7fad0d1df4e2> in <module>
#       1 #Comprobación de valores nulos
# ----> 2 print(pd.isnull(df).any())
#       3 print()
#       4 print("Filas totales:", len(df))
#       5 print("Filas con algún valor nulo:", len([x for x in df.isnull().any(axis=1) if x]))
#
# NameError: name 'pd' is not defined

# %%
#Procesado de la columna "adult"
#Aqui observamos que hay valores no booleanos que debemos eliminar, y además observamos que
#las películas con valor True son muy escasas en comparación con las que tienen valor False,
#por lo que vamos a eliminar las filas anómalas y quitar la columna "adult"
print(df["adult"].value_counts())
print()

drop_list = []
for i in range(len(df)):
    if df["adult"][i] != "False":
        drop_list.append(i)
df.drop(index=drop_list, inplace=True)
print(df["adult"].value_counts())
print()

df.drop(columns=["adult"], inplace=True)
print(list(df))
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  - Written by Ørnås                                                                                                                   1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
# Name: adult, dtype: int64
#
# False    45454
# Name: adult, dtype: int64
#
# ['belongs_to_collection', 'budget', 'genres', 'original_language', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'tagline', 'title', 'vote_average', 'vote_count']

# %%
# title, tagline, overview y belongs_to_collection

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re

replaces = [("i'm", "i am"),
            ("you're", "you are"),
            ("we're", "we are"),
            ("they're", "they are"),
            
            ("that's", "that is"),
            ("there's", "there is"),
            ("who's", "who is"), 
            ("what's", "what is"),
            
            ("isn't", "is not"),
            ("aren't", "are not"), 
            ("can't", "cannot"),
            ("haven't", "have not"),
            ("won't", "will not"),
            ("doesn't", "does not"),
            ("don't", "do not"),
            ("didn't", "did not"),
            ("couldn't", "could not"),
            ("shouldn't", "should not"),
            ("wasn't", "was not"),
            ("weren't", "were not"),
            ("hasn't", "has not"),
            ("hadn't", "had not"),
            
            ("we'd", "we would"),
            ("he'd", "he would"),
            ("you'd", "you would"),
            ("they'd", "they would"), 
            ("who'd", "who would"),
            ("wouldn't", "would not"),
            
            ("i'll", "i will"),
            ("you'll", "you will"),
            ("he'll", "he will"),
            ("she'll", "she will"),
            ("it'll", "it will"),
            ("we'll", "we will"),
            ("they'll", "they will"),
            
            ("i've", "i have"),
            ("you've", "you have"),
            ("we've", "we have"),
            ("they've", "they've"),
            ("&", " and ")
           ]

def sub_contractions(text):
    new_text = text
    for r in replaces:
        new_text = re.sub(f"{r[0]}", f"{r[1]}", new_text)
    return new_text

lemmatizer = WordNetLemmatizer()
def preprocess_text(text):
    if type(text) is float:  #Comprobando valores nulos, expresados como un float NaN
        ret_text = []
    else:
        new_text = text.lower()
        new_text = sub_contractions(new_text)
        new_text = re.sub("[^A-Za-zÀ-ÖØ-öø-ÿ0-9 ]", "", new_text)
        
        tok_text = word_tokenize(new_text)
        stop_words = list(stopwords.words("english"))
        tok_text = [word for word in tok_text if word not in stop_words]
        tok_text = [lemmatizer.lemmatize(word) for word in tok_text]
        ret_text = tok_text
        
        """ Processing feedback
        joint_text = " ".join(tok_text)
        print(new_text)
        print(joint_text)
        print() #"""
        
    return ret_text

# %%
df["preprocessed_tagline"] = df["tagline"].apply(preprocess_text)
df["preprocessed_tagline"]
# Out:
# 0                                                       []
# 1                        [roll, dice, unleash, excitement]
# 2        [still, yelling, still, fighting, still, ready...
# 3                [friend, people, let, never, let, forget]
# 4                [world, back, normal, he, surprise, life]
# 5                              [los, angeles, crime, saga]
# 6           [cordially, invited, surprising, merger, year]
# 7                                     [original, bad, boy]
# 8                                   [terror, go, overtime]
# 9                                [limit, fear, substitute]
# 10                [powerful, man, world, one, thing, want]
# 11                                                      []
# 12                           [part, dog, part, wolf, hero]
# 13       [triumphant, victory, bitter, defeat, changed,...
# 14       [course, set, turning, back, prepare, weapon, ...
# 15                               [one, stay, top, forever]
# 16                               [lose, heart, come, sens]
# 17       [twelve, outrageous, guest, four, scandalous, ...
# 18                     [new, animal, new, adventure, hair]
# 19                                         [get, get, way]
# 20             [mob, tough, nothing, like, show, business]
# 21       [one, man, copying, notorious, killer, history...
# 22       [shadow, life, business, death, one, man, foun...
# 23              [extraordinary, encounter, another, human]
# 24                                             [love, way]
# 25                           [envy, greed, jealousy, love]
# 26                      [every, woman, girl, left, behind]
# 27                                                      []
# 28                                  [happily, ever, dream]
# 29          [1930s, shanghai, violence, problem, solution]
# 30                            [broke, rule, changed, life]
# 31                                       [future, history]
# 32                                                      []
# 33                            [little, pig, go, long, way]
# 34                                   [love, unusual, true]
# 35                                                      []
# 36                                                      []
# 37       [two, identical, stranger, two, different, wor...
# 38                     [sex, clothes, popularity, problem]
# 39                                                      []
# 40                                  [smile, murder, smile]
# 41                    [daring, heist, color, count, green]
# 42                                                      []
# 43                              [nothing, world, prepared]
# 44                             [wanted, little, attention]
# 45                                 [beauty, pattern, life]
# 46                   [seven, deadly, sin, seven, way, die]
# 47                          [american, legend, come, life]
# 48                                                      []
# 49                [five, criminal, one, line, coincidence]
# 50                                    [shes, angel, mercy]
# 51                                                      []
# 52                                                      []
# 53                                   [biggest, kick, year]
# 54                          [toughest, act, follow, dream]
# 55                                                      []
# 56                          [every, yearuntil, get, right]
# 57                                                      []
# 58                                                      []
# 59                                                      []
# 60                                        [justice, fails]
# 61                           [life, changed, one, changed]
# 62       [finally, movie, prof, justice, always, poetic...
# 63                  [new, comedy, love, laughter, larceny]
# 64       [bud, doyle, save, world, gon, na, save, world...
# 65       [god, made, simple, science, made, god, want, ...
# 66       [never, old, believe, dream, young, make, one,...
# 67                                                      []
# 68                           [lot, go, thursday, saturday]
# 69        [one, night, stand, freedom, going, hell, night]
# 70         [he, cop, edge, shes, woman, dangerous, secret]
# 71                                [anxiety, love, company]
# 72       [time, chaos, world, change, moved, book, coul...
# 73                            [gave, flower, gave, chance]
# 74                                        [comedy, kid, u]
# 75                                    [last, scream, hear]
# 76                                                      []
# 77                          [life, cross, others, collide]
# 78                                               [defense]
# 79                                                      []
# 80                          [protect, love, honor, avenge]
# 81       [motion, picture, celebrates, everything, love...
# 82                                                      []
# 83                                                      []
# 84       [elegant, seduction, erotic, deception, stunni...
# 85                                                      []
# 86       [he, turn, five, star, hotel, three, ring, cir...
# 87                                    [one, every, family]
# 88                                                      []
# 89                                                      []
# 90                           [untold, story, jekyll, hyde]
# 91                        [comic, tale, horror, seduction]
# 92                       [good, time, never, seemed, good]
# 93                                [prepare, go, ballistic]
# 94       [drama, passion, intrigue, rehearsal, even, st...
# 95               [three, young, friend, one, last, chance]
# 96                            [one, leaf, without, paying]
# 97                                                      []
# 98       [started, shootout, rainswept, street, ended, ...
# 99               [really, criminal, everyones, got, dream]
# 100                                                     []
# 101          [loved, lost, let, memory, die, tell, killed]
# 102                                 [play, golf, destroys]
# 103      [path, francesca, johnson, future, seems, dest...
# 104                                                     []
# 105                            [set, sail, muppet, mayhem]
# 106      [moment, fashion, art, entertainment, come, to...
# 107                                                     []
# 108              [every, man, dy, every, man, truly, life]
# 109      [every, street, every, city, nobody, dream, so...
# 110                                [fear, stuntman, equal]
# 111                       [murder, suspect, shadow, doubt]
# 112                [found, way, preserve, memory, forever]
# 113                                                     []
# 114      [perhaps, hitler, best, known, victim, anne, f...
# 115                                                     []
# 116                     [comedy, romantically, challenged]
# 117      [two, brother, one, fortune, zero, chance, share]
# 118                         [dream, make, difference, sun]
# 119                                                     []
# 120                                       [player, played]
# 121                                [difference, day, make]
# 122      [golden, age, cinema, everyone, dream, becomin...
# 123      [comedy, sex, love, family, accident, waiting,...
# 124         [brand, new, beginning, adventure, never, end]
# 125                                                     []
# 126                        [haunting, real, life, mystery]
# 127      [thing, stand, way, fate, true, love, little, ...
# 128                                                     []
# 129       [sometimes, brightest, star, one, shine, within]
# 130                                     [fantasy, go, far]
# 131                                                     []
# 132                                                     []
# 133      [rusty, sub, rebel, commander, renegade, crew,...
# 134                                                     []
# 135              [centerfold, revealed, everything, truth]
# 136                                                     []
# 137                                                     []
# 138                             [every, day, one, deserve]
# 139                                                 [come]
# 140                                                     []
# 141      [sometimes, best, friend, one, known, whole, l...
# 142                                     [whatcha, gon, na]
# 143      [sweeping, highland, china, boy, begin, magica...
# 144         [true, story, death, innocence, birth, artist]
# 145                                                     []
# 146      [accountancy, murder, amnesia, torture, ecstas...
# 147                                     [houston, problem]
# 148      [honor, made, man, courage, made, hero, histor...
# 149         [dark, sunlight, make, different, keep, alive]
# 150                               [courage, truth, always]
# 151                   [luis, bunuel, masterpiece, erotica]
# 152                                       [truth, witness]
# 153                            [welcome, planet, brooklyn]
# 154                 [tell, ya, another, thing, beer, suck]
# 155                                       [get, afterlife]
# 156                    [murder, street, everyone, suspect]
# 157                                   [endangered, specie]
# 158                                    [danger, run, deep]
# 159                   [weird, sex, obsession, comic, book]
# 160                    [smoke, clear, mean, he, reloading]
# 161      [private, detective, easy, rawlins, caught, wr...
# 162                  [think, fast, look, alive, die, hard]
# 163                              [sex, violence, whatever]
# 164                                         [escape, past]
# 165                        [greatest, battle, would, love]
# 166      [adventure, back, fun, back, willys, back, tim...
# 167                            [right, wrong, fun, boring]
# 168                 [love, adventure, one, sure, positive]
# 169            [hottest, data, earth, coolest, head, town]
# 170                                [future, one, man, law]
# 171                      [truth, justice, five, buck, day]
# 172                                                     []
# 173      [nick, discover, first, rule, filmmaking, firs...
# 174                         [trust, nothing, except, fear]
# 175                                                     []
# 176                                [wild, sexy, adventure]
# 177                                           [shop, work]
# 178                                                [power]
# 179               [virginity, sex, big, cry, salty, topic]
# 180                            [speak, scream, beg, mercy]
# 181                          [unseen, unforgiving, undead]
# 182      [driver, license, credit, card, passport, acce...
# 183                                                [ready]
# 184                    [sassy, savvy, definitely, cluedin]
# 185      [ancient, ground, edge, world, evil, born, hea...
# 186                             [twisted, christmas, ever]
# 187                          [21st, century, nobody, safe]
# 188      [intimacy, forbidden, passion, sin, love, defi...
# 189                          [happens, stage, half, story]
# 190      [beyond, wildest, dream, beyond, wildest, fant...
# 191                                      [smoke, laughter]
# 192      [story, husband, wife, parent, child, natural,...
# 193                                                 [time]
# 194                                                     []
# 195                                           [know, want]
# 196                            [film, young, lover, world]
# 197                                                     []
# 198                         [really, believe, magic, find]
# 199      [touched, genius, cursed, madness, blinded, love]
# 200                                 [attitude, everything]
# 201           [last, time, rocked, boat, time, sky, limit]
# 202               [sometimes, find, hero, unlikely, place]
# 203                                                     []
# 204                [man, search, woman, need, story, fate]
# 205         [beyond, horizon, lie, secret, new, beginning]
# 206                              [reality, switched, side]
# 207                           [name, legendary, man, real]
# 208          [greatest, lesson, life, one, learned, heart]
# 209      [wanted, great, adventure, got, mad, max, grab...
# 210      [moving, poignant, story, set, corrupt, politi...
# 211                 [know, face, begin, understand, story]
# 212            [greatest, romance, life, last, one, night]
# 213                [billy, going, back, school, way, back]
# 214                      [something, capture, imagination]
# 215      [motion, picture, celebrates, art, survival, g...
# 216                      [best, cure, disease, friendship]
# 217                               [hideous, hungry, loose]
# 218                                                     []
# 219                                    [serve, mean, like]
# 220      [story, man, thought, greatest, lover, world, ...
# 221                                           [sex, power]
# 222                                                     []
# 223                           [taking, crime, new, height]
# 224                      [fate, visit, way, never, expect]
# 225                               [prepare, moment, truth]
# 226      [sometimes, accident, unhappy, woman, best, fr...
# 227                                         [one, missing]
# 228                                                     []
# 229      [world, temptation, obsession, deadliest, desire]
# 230                  [crack, case, two, cop, flash, badge]
# 231             [came, making, bad, movie, ed, wood, best]
# 232                                                     []
# 233                                                     []
# 234                      [partner, survival, friend, life]
# 235      [story, father, could, closerto, driving, son,...
# 236                [bought, back, dead, come, back, alone]
# 237      [unleash, imagination, come, along, magical, j...
# 238               [où, sarrête, le, pouvoir, de, sa, voix]
# 239                              [talking, pig, made, big]
# 240                                [original, green, hero]
# 241               [world, filled, violence, weapon, truth]
# 242                           [extraordinary, true, story]
# 243      [secret, world, one, could, see, came, crime, ...
# 244                                                     []
# 245                                                     []
# 246      [run, fastest, jump, highest, sure, getting, l...
# 247      [he, trapped, world, killing, art, revenge, ob...
# 248                                          [think, love]
# 249                                 [drink, live, forever]
# 250      [powerful, man, torn, love, one, woman, secret...
# 251                                                     []
# 252                               [nothing, inconceivable]
# 253      [buried, deep, florida, everglades, secret, sa...
# 254                                                [joust]
# 255                                                     []
# 256              [long, time, ago, galaxy, far, far, away]
# 257      [story, lived, heart, generation, come, screen...
# 258                    [every, girl, everywhere, princess]
# 259                                                     []
# 260                                                     []
# 261      [titas, kitchen, ordinary, spice, become, reci...
# 262                       [fall, innocence, legend, begin]
# 263      [he, looking, good, men, guy, old, enough, shave]
# 264                       [brother, blood, partner, crime]
# 265                    [mother, warrior, sister, survivor]
# 266                                                     []
# 267                                [decides, make, mother]
# 268                                                     []
# 269                                        [warned, alive]
# 270      [jack, want, marry, ben, mother, string, attac...
# 271                                                     []
# 272                [get, enough, good, thing, first, find]
# 273                    [really, believe, anything, happen]
# 274      [love, great, marriage, completely, different,...
# 275                             [three, generation, dream]
# 276                             [trial, brought, alcatraz]
# 277      [town, nothing, ever, happens, everything, hap...
# 278      [heart, soul, language, mysterya, mystery, cal...
# 279                                  [thing, matter, ride]
# 280       [toughest, city, world, deserves, toughest, cop]
# 281      [psychological, terror, beyond, wildest, night...
# 282                                  [future, got, darker]
# 283                 [sometimes, break, vow, keep, promise]
# 284                              [medium, made, superstar]
# 285                           [love, story, written, star]
# 286      [family, crisis, life, chaos, nothing, powerfu...
# 287      [passion, seduction, betrayal, lily, wanted, l...
# 288      [animal, carry, deadly, virus, greatest, medic...
# 289            [want, job, done, well, hire, professional]
# 290                    [way, finding, family, found, love]
# 291                                                     []
# 292                           [character, mean, character]
# 293      [people, called, hero, fbi, called, public, en...
# 294                                                     []
# 295      [world, ritual, place, secret, man, must, choo...
# 296      [fifty, million, people, watched, one, saw, th...
# 297                                                     []
# 298                                                     []
# 299                                 [think, quick, enough]
# 300                                                     []
# 301      [world, hottest, fashion, show, murder, everyo...
# 302                                                     []
# 303                                                     []
# 304                                                     []
# 305                                                     []
# 306                                                     []
# 307                              [trusting, child, deadly]
# 308                                                     []
# 309      [enchanting, classic, destined, capture, heart...
# 310                         [land, sea, place, myth, real]
# 311      [government, taught, kill, he, using, skill, h...
# 312        [take, million, light, year, home, bring, back]
# 313                                    [dad, santa, claus]
# 314                [fear, hold, prisoner, hope, set, free]
# 315        [award, winning, thriller, thatll, bury, laugh]
# 316                      [thriller, nothing, black, white]
# 317                                                     []
# 318                                          [life, movie]
# 319                                               [sum, u]
# 320      [stupid, trick, outrageous, chaos, total, dest...
# 321                                                     []
# 322          [2033, justice, ride, tank, wear, lip, gloss]
# 323                               [ready, deadtime, story]
# 324                                           [boldly, go]
# 325                                       [chill, chilled]
# 326                               [better, worse, forever]
# 327                                        [beware, child]
# 328                      [first, succeed, lower, standard]
# 329                                                     []
# 330      [passion, betrayal, murder, still, place, like...
# 331                         [surviving, street, rehearsal]
# 332                [film, love, findin, last, place, look]
# 333                          [justice, need, new, program]
# 334                           [story, love, second, sight]
# 335                                                     []
# 336                        [got, one, life, live, gon, na]
# 337                               [success, best, revenge]
# 338                                      [friend, forever]
# 339                          [he, best, actually, he, one]
# 340      [shes, back, looking, gorgeous, outrageous, ev...
# 341                                                     []
# 342                     [kinky, voyage, full, head, steam]
# 343                                                     []
# 344                   [war, drug, would, lead, war, power]
# 345      [district, attorney, conviction, new, lawyer, ...
# 346                                                     []
# 347                                                     []
# 348                                  [real, love, forever]
# 349             [everyone, hated, baseball, legend, loved]
# 350                                        [yabbadabbadoo]
# 351               [world, never, seen, eye, forrest, gump]
# 352                     [five, good, reason, stay, single]
# 353                                                     []
# 354         [lisette, everyday, become, independence, day]
# 355                            [romance, never, dangerous]
# 356                       [cop, waitress, lottery, ticket]
# 357                                                     []
# 358                                                     []
# 359      [life, greatest, adventure, finding, place, ci...
# 360         [magical, journey, place, past, present, meet]
# 361                            [one, two, freddys, coming]
# 362                                           [zero, hero]
# 363              [hand, deck, card, thing, dangerous, gun]
# 364      [new, york, 1920s, place, algonquin, person, k...
# 365       [mad, bomber, loose, anyone, stop, himso, frank]
# 366      [behindthelines, look, work, marriage, form, c...
# 367                                     [comedy, love, 90]
# 368                                       [nothing, seems]
# 369      [adventure, big, even, world, richest, kid, af...
# 370                      [life, best, journey, take, home]
# 371                                             [vacation]
# 372                               [get, ready, rush, hour]
# 373        [two, side, every, relationship, trust, either]
# 374      [killed, wife, ten, year, ago, still, time, sa...
# 375                                    [said, never, said]
# 376        [good, time, bad, time, man, love, woman, time]
# 377                                               [animal]
# 378          [epic, story, love, adventure, lawless, land]
# 379        [bribery, blackmail, murder, speciality, house]
# 380                  [extraordinary, tale, ordinary, hero]
# 381              [fate, made, hostage, medium, made, star]
# 382                        [he, armed, dangerously, funny]
# 383                      [3, tale, love, lust, liberation]
# 384                                                     []
# 385                       [gogo, wild, ride, action, girl]
# 386                                        [love, courage]
# 387                     [nursery, crime, epic, proportion]
# 388                                   [fight, save, world]
# 389                                                     []
# 390                                       [began, whisper]
# 391             [wrong, people, wrong, place, wrong, time]
# 392                                  [he, whatever, scare]
# 393                                                     []
# 394                            [first, date, robbed, bank]
# 395                [would, sacrifice, everything, hereven]
# 396                            [love, deadliest, illusion]
# 397                                                     []
# 398                                                     []
# 399                                                     []
# 400      [throughout, time, hunted, fulfilling, prophec...
# 401                                                     []
# 402                            [lived, good, book, lately]
# 403                                     [hang, ride, life]
# 404                               [game, play, game, play]
# 405                        [family, got, little, stranger]
# 406                  [uncut, unrated, unbelievably, funny]
# 407      [world, tradition, age, innocence, dared, brea...
# 408                                    [amp, nobody, home]
# 409                                                     []
# 410                      [look, thrill, action, adventure]
# 411           [dangerous, time, woman, good, time, friend]
# 412                       [american, anti, american, love]
# 413                      [hector, history, way, repeating]
# 414                     [day, moved, beverly, hill, moved]
# 415                                                     []
# 416                                                     []
# 417                                            [see, kill]
# 418                                   [5, 4, 3, 2, 1times]
# 419                                                     []
# 420                [world, secret, love, powerful, weapon]
# 421      [imagine, gone, someone, else, living, inside,...
# 422      [beyond, love, beyond, obsession, hide, someth...
# 423      [one, man, life, neighborhood, another, man, o...
# 424      [he, setting, sail, high, sea, without, rudder...
# 425      [three, boy, journey, discovery, hollywood, ea...
# 426        [he, got, good, future, live, past, next, week]
# 427                                                     []
# 428                                                     []
# 429                                    [height, adventure]
# 430                   [young, one, parental, unit, summon]
# 431      [heat, desire, love, turn, deception, nothing,...
# 432                                                     []
# 433                                                     []
# 434                    [turbulence, redemption, hollywood]
# 435         [country, anybody, become, president, anybody]
# 436                                             [see, bud]
# 437      [21st, century, dangerous, cop, 21st, century,...
# 438                                                     []
# 439                                                     []
# 440                   [sex, murder, revenge, never, funny]
# 441                                                     []
# 442                  [two, woman, three, men, one, secret]
# 443                              [people, afraid, nothing]
# 444                               [first, driveby, comedy]
# 445      [want, degree, go, harvard, want, education, g...
# 446                                        [evil, patient]
# 447                                                     []
# 448            [thought, nothing, seductive, money, wrong]
# 449                                [power, murder, resist]
# 450                               [far, would, go, friend]
# 451                                                     []
# 452      [murdered, wife, onearmed, man, obsessed, dete...
# 453                              [warrior, leader, legend]
# 454                                                     []
# 455             [he, getting, mad, he, getting, even, dad]
# 456                                                 [girl]
# 457                                                     []
# 458      [shes, finally, met, match, he, handsome, weal...
# 459                                           [hunt, kill]
# 460                       [amazing, true, story, survival]
# 461                                                 [deux]
# 462                           [sex, lie, fantasy, unrated]
# 463                                                     []
# 464                                                     []
# 465               [bachelor, party, gon, na, bring, house]
# 466                         [took, fall, guy, threw, hoop]
# 467                                                     []
# 468      [sleep, tight, america, safety, free, world, r...
# 469      [assassin, loose, president, danger, one, man,...
# 470      [falsely, accused, wrongly, imprisoned, fought...
# 471                             [summer, never, much, fun]
# 472                           [need, heart, heart, broken]
# 473                                                     []
# 474                         [move, whisper, even, breathe]
# 475                 [adventure, 65, million, year, making]
# 476                           [fear, never, travel, alone]
# 477                                                     []
# 478              [world, turn, upside, trick, coming, top]
# 479                                [best, friend, forever]
# 480                                       [movie, anymore]
# 481      [he, talent, agent, shes, thief, look, like, t...
# 482                                                     []
# 483                                                     []
# 484      [spermbank, asked, tall, intelligent, black, m...
# 485                   [doctor, playing, god, thought, god]
# 486      [fatherless, boy, almost, given, dream, one, m...
# 487                  [keaton, allen, reunited, fun, flick]
# 488                                          [truth, real]
# 489                                   [fasten, seat, belt]
# 490                                                     []
# 491                                                     []
# 492      [romance, mischief, seduction, revenge, remark...
# 493              [everything, make, dangerous, make, love]
# 494      [sometimes, love, stranger, sometimes, someone...
# 495      [make, dinner, window, read, bedtime, story, s...
# 496                                                     []
# 497                                  [say, good, guy, guy]
# 498                   [shopping, spree, morally, bankrupt]
# 499                                          [guard, wall]
# 500              [family, comedy, appeal, child, everyone]
# 501                                                     []
# 502                                                     []
# 503      [one, would, take, case, one, man, willing, ta...
# 504                                                     []
# 505                                      [street, romance]
# 506      [different, world, come, prove, gritty, world,...
# 507                                           [trust, one]
# 508                      [station, wbn, hit, keep, coming]
# 509                        [might, hostage, guy, criminal]
# 510                                       [diamond, rough]
# 511          [one, man, mission, teach, proud, impossible]
# 512      [collision, east, west, conspiracy, seduction,...
# 513                                 [comedy, heart, organ]
# 514                                   [he, back, lay, law]
# 515      [legend, coming, find, robin, hood, put, littl...
# 516                  [story, cop, wanted, bad, got, worse]
# 517                           [give, smack, head, special]
# 518                                        [woman, search]
# 519                   [size, dog, fight, size, fight, dog]
# 520                                                     []
# 521                                                     []
# 522        [whoever, save, one, life, save, world, entire]
# 523               [praying, miracle, got, steve, nebraska]
# 524                  [every, journey, begin, single, move]
# 525                                                     []
# 526      [timeless, tale, special, place, magic, hope, ...
# 527                [every, mom, want, wanted, murder, one]
# 528                                         [shadow, know]
# 529                                                     []
# 530                     [short, cut, raise, roof, america]
# 531           [twist, fate, brought, something, wonderful]
# 532      [1930s, artist, model, scandalized, nation, co...
# 533           [paul, every, person, new, door, new, world]
# 534      [someone, never, met, someone, never, saw, som...
# 535                                          [like, watch]
# 536                            [man, made, match, problem]
# 537                              [he, relative, nightmare]
# 538                                    [honeymoon, killer]
# 539                         [put, water, want, make, wave]
# 540                                                     []
# 541                                           [aint, game]
# 542                                    [ultimate, manhunt]
# 543                                           [fall, kill]
# 544                                        [sound, genius]
# 545              [one, girl, two, guy, three, possibility]
# 546      [ghoulish, tale, wicked, humor, stunning, anim...
# 547                                             [one, one]
# 548                                      [justice, coming]
# 549      [one, juror, question, guilt, innocence, matte...
# 550      [stealing, cheating, killing, said, romance, d...
# 551                               [changed, way, campaign]
# 552                         [adventure, imagination, hold]
# 553                                                     []
# 554                                                     []
# 555                                      [hurt, one, love]
# 556                               [girl, want, play, doll]
# 557              [need, god, heaven, change, lousy, world]
# 558      [supposed, routine, prisoner, transfer, ordina...
# 559                                                     []
# 560                                                     []
# 561                                                     []
# 562                                                     []
# 563      [major, league, experience, minor, problem, he...
# 564                      [growing, easy, everybody, would]
# 565                                                     []
# 566                                                     []
# 567                                     [ciao, professore]
# 568                        [gripping, comedy, letting, go]
# 569                              [mischief, love, company]
# 570                                                     []
# 571              [greatest, adventure, finding, way, home]
# 572                                                     []
# 573               [everything, dreamed, nothing, expected]
# 574                                                     []
# 575                                                     []
# 576                                                     []
# 577                                                     []
# 578                                                     []
# 579                      [family, comedy, without, family]
# 580                                  [love, last, forever]
# 581                                        [wish, granted]
# 582                                    [nothing, personal]
# 583      [inside, everyone, frontier, waiting, discovered]
# 584                       [expert, fist, gun, afraid, use]
# 585                 [ever, danced, devil, pale, moonlight]
# 586      [enter, mind, killer, must, challenge, mind, m...
# 587      [happiest, dopiest, grumpiest, sneeziest, movi...
# 588                   [beautiful, love, story, ever, told]
# 589                     [anyone, ever, wished, upon, star]
# 590                              [knew, much, fun, hooker]
# 591                                                     []
# 592      [want, spend, two, hour, movie, theatre, go, h...
# 593           [one, jagged, twisting, ride, never, forget]
# 594      [defied, thousand, year, tradition, one, momen...
# 595                                                     []
# 596                                                     []
# 597            [perfectly, bad, day, came, along, spoiled]
# 598                               [evil, come, call, name]
# 599                                                     []
# 600                         [lot, happen, middle, nowhere]
# 601                      [favorite, talking, animal, back]
# 602                       [step, beyond, science, fiction]
# 603      [year, past, present, future, meet, crossroad,...
# 604        [something, magical, unfold, unexpected, place]
# 605                  [passionate, tale, forbidden, secret]
# 606                                                     []
# 607                            [laugh, till, heart, break]
# 608                   [tunefilled, animated, extravaganza]
# 609                                 [every, woman, secret]
# 610                                                     []
# 611                     [minor, league, major, friendship]
# 612                                       [battle, winner]
# 613                                                     []
# 614            [met, fell, love, baby, necessarily, order]
# 615                                                     []
# 616                                                     []
# 617                                            [play, pay]
# 618                 [love, sex, life, death, house, table]
# 619      [sooner, later, man, wear, two, face, forgets,...
# 620                         [action, speaks, louder, word]
# 621                     [story, first, love, last, chance]
# 622      [heaven, help, u, look, back, adventure, 2, li...
# 623              [fight, fascism, begin, fight, stalinism]
# 624      [hilarious, heartringing, fable, life, love, h...
# 625      [world, toughest, cop, getting, brand, new, pa...
# 626                         [family, everything, relative]
# 627                                                     []
# 628      [ever, wanted, honest, week, pay, honest, day,...
# 629      [shes, proper, shes, fitting, shes, british, j...
# 630                           [fresh, sassy, sexy, comedy]
# 631            [two, woman, one, man, combination, murder]
# 632               [city, jungle, better, prepared, others]
# 633                                                     []
# 634                                                     []
# 635                                                     []
# 636                                                     []
# 637         [medal, honor, search, justice, battle, truth]
# 638                                   [expect, impossible]
# 639                                                     []
# 640      [remarkable, story, one, woman, unbreakable, s...
# 641                                                     []
# 642      [two, apartment, two, woman, one, shocking, my...
# 643                                              [believe]
# 644                                                     []
# 645                                                     []
# 646         [newest, coach, nba, got, knicks, right, want]
# 647                                  [god, crazy, berserk]
# 648                                 [today, he, man, used]
# 649             [passion, ten, envy, eleven, murder, noon]
# 650      [really, life, appear, desillusions, good, fun...
# 651                           [adventure, big, grow, tree]
# 652                              [together, forever, else]
# 653                                          [shove, mind]
# 654                      [comedy, wife, husband, hit, man]
# 655                                                     []
# 656                    [student, teacher, love, forbidden]
# 657            [caught, honor, revenge, far, one, man, go]
# 658                                                     []
# 659                                                     []
# 660      [every, year, hollywood, make, hundred, movie,...
# 661                                                     []
# 662                                      [get, ready, jam]
# 663                               [see, barbarella, thing]
# 664      [night, adventure, becomes, one, woman, desper...
# 665                                     [live, suck, bite]
# 666                                                     []
# 667                               [unforgettable, romance]
# 668      [suddenly, word, alphaville, secret, agent, br...
# 669                                                     []
# 670                                                     []
# 671                                                     []
# 672                                                     []
# 673                                                     []
# 674                                                     []
# 675             [topsecret, mission, gigantic, proportion]
# 676                                     [love, hope, wall]
# 677                     [story, girl, going, filthy, rich]
# 678              [part, man, part, machine, total, weapon]
# 679                                                     []
# 680                                                     []
# 681                                           [trust, one]
# 682                                                     []
# 683      [met, man, dream, along, came, husband, ruin, ...
# 684      [1939, elena, went, paris, searching, voice, w...
# 685                                                     []
# 686          [everyone, outside, looking, moment, arrived]
# 687                                                     []
# 688                                                     []
# 689                         [one, stay, innocent, forever]
# 690                                         [go, distance]
# 691                                                     []
# 692                                   [got, ta, represent]
# 693                                [america, los, angeles]
# 694           [brians, discover, woman, love, woman, love]
# 695                       [first, disney, movie, attitude]
# 696                                      [beat, em, steal]
# 697               [summer, finally, safe, go, back, water]
# 698                                        [far, go, love]
# 699        [surrounded, danger, risk, everything, freedom]
# 700                       [one, survive, becoming, legend]
# 701                                                     []
# 702                               [easy, kill, hard, love]
# 703                                                     []
# 704                                      [born, yesterday]
# 705                           [sometimes, get, life, make]
# 706                         [mind, stand, shocking, truth]
# 707                                                     []
# 708                              [welcome, witching, hour]
# 709                    [find, perfect, contendermake, one]
# 710                            [sometimes, justice, crime]
# 711                                                     []
# 712      [discovered, new, branch, family, tree, one, nut]
# 713                                                     []
# 714      [excop, obsessed, unsolved, murder, trusting, ...
# 715                     [original, bad, boy, stepping, 96]
# 716      [alcatraz, one, man, ever, broken, five, milli...
# 717                [one, bad, apple, spoil, whole, lineup]
# 718                                 [zombie, gun, sex, oh]
# 719                                   [dark, side, nature]
# 720                                           [call, babe]
# 721                                                     []
# 722                                                     []
# 723                             [found, voice, need, body]
# 724                               [let, curse, fit, crime]
# 725                    [action, woman, half, intelligence]
# 726                                                     []
# 727      [oscarwinning, creator, grand, day, wrong, tro...
# 728                                                     []
# 729                   [american, apple, pie, twice, smart]
# 730      [greatest, danger, facing, world, planet, best...
# 731                                  [thrill, fun, action]
# 732                            [hotline, suspense, comedy]
# 733                                                     []
# 734                                                     []
# 735                                                     []
# 736                           [friendship, worth, fortune]
# 737      [famed, spectacular, adventure, story, filmed,...
# 738                                                     []
# 739                                                     []
# 740                                                     []
# 741      [story, vietnam, veteran, memorial, inspiring,...
# 742                                                     []
# 743                                           [slam, evil]
# 744                   [people, get, trouble, matter, wear]
# 745                             [school, end, life, begin]
# 746                                                     []
# 747      [jack, powell, tackle, biggest, adventure, eve...
# 748                                 [get, one, shot, fame]
# 749               [love, chain, love, nature, chain, life]
# 750                  [two, friend, two, world, one, dream]
# 751                                                     []
# 752                                                     []
# 753                                       [journey, hyena]
# 754                                                     []
# 755                                 [ultimate, orgy, evil]
# 756                                 [hear, clock, ticking]
# 757                                                     []
# 758                                         [choose, life]
# 759                                                     []
# 760                 [earth, take, good, look, might, last]
# 761                               [beautiful, place, love]
# 762         [fan, favorite, player, one, favorite, target]
# 763                                                     []
# 764                                   [thing, free, cable]
# 765                    [would, want, meet, pinhead, alley]
# 766                         [erase, past, protect, future]
# 767                                                     []
# 768         [inside, sherman, klump, party, animal, break]
# 769                                                     []
# 770                                                     []
# 771                                                     []
# 772                                                     []
# 773                                                     []
# 774                                                     []
# 775                                                     []
# 776                                                     []
# 777                                    [air, escape, time]
# 778                                         [rest, wicked]
# 779           [john, sayles, invite, return, scene, crime]
# 780                                                 [case]
# 781                               [thing, life, explained]
# 782      [movie, everyone, want, get, married, stay, si...
# 783      [romantic, comedy, two, brother, one, thing, c...
# 784                      [experience, time, never, forget]
# 785                                  [plan, worth, nickle]
# 786                                                     []
# 787      [missing, father, desperate, search, unforgett...
# 788                                             [see, run]
# 789                   [world, powerful, genie, met, match]
# 790                           [time, move, one, direction]
# 791      [he, got, 5, day, go, coasttocoast, one, big, ...
# 792                                                     []
# 793                                                     []
# 794                                   [obsesssion, murder]
# 795                             [everything, change, stay]
# 796                                                     []
# 797                         [torridtantalizingtempestuous]
# 798                                                     []
# 799                                                     []
# 800                                                     []
# 801      [macho, cop, find, relationship, gay, man, que...
# 802                                                     []
# 803                                                     []
# 804                       [new, angle, classic, tale, lie]
# 805                              [sex, bug, rock, n, roll]
# 806                            [get, mad, get, everything]
# 807                                   [fight, right, love]
# 808                                  [someone, going, pay]
# 809              [dangerous, mind, terrible, thing, waste]
# 810                                [aint, nothin, gstring]
# 811        [took, 17, year, learn, rule, one, week, break]
# 812                                 [reaction, time, 8496]
# ...
# 45196                           [putting, ex, back, texas]
# 45197    [dedicated, brilliant, inspiring, underpaid, m...
# 45198                                                   []
# 45199                                                   []
# 45200                                                   []
# 45201                               [movie, movie, poster]
# 45202                                      [careful, wish]
# 45203                                                   []
# 45204                 [forgive, u, advance, wild, weekend]
# 45205                        [1995, people, harder, reach]
# 45206                                         [time, knew]
# 45207                                                   []
# 45208                                                   []
# 45209                                                   []
# 45210                                                   []
# 45211                                  [save, save, world]
# 45212                                                   []
# 45213                                                   []
# 45214                    [fittest, earth, decade, fitness]
# 45215                                                   []
# 45216                                                   []
# 45217                                                   []
# 45218                                                   []
# 45219                                                   []
# 45220    [amid, epic, landscape, mahabharata, stage, se...
# 45221                                         [life, hard]
# 45222                                                   []
# 45223                                                   []
# 45224                                                   []
# 45225                                                   []
# 45226                                                   []
# 45227                                                   []
# 45228                                                   []
# 45229                                                   []
# 45230                                                   []
# 45231                                                   []
# 45232                                                   []
# 45233                                                   []
# 45234                                                   []
# 45235                                                   []
# 45236                                                   []
# 45237     [daring, delicious, gayest, comedyromance, year]
# 45238                                                   []
# 45239                                                   []
# 45240                  [young, willing, oh, eager, please]
# 45241                           [straight, way, classroom]
# 45242                                                   []
# 45243                                                   []
# 45244                                                   []
# 45245                                                   []
# 45246                                                   []
# 45247                                                   []
# 45248                                                   []
# 45249                                                   []
# 45250                                                   []
# 45251                                                   []
# 45252                                    [one, shot, miss]
# 45253                            [every, question, answer]
# 45254                                                   []
# 45255                              [beyond, limit, museum]
# 45256                                     [past, prologue]
# 45257                                                   []
# 45258                                   [long, live, evil]
# 45259                                                   []
# 45260                                                   []
# 45261                                                   []
# 45262                                                   []
# 45263                                                   []
# 45264                                                   []
# 45265                                                   []
# 45266               [australia, v, australia, nobody, win]
# 45267                                                   []
# 45268                                                   []
# 45269                      [comedy, found, darkest, place]
# 45270                                                   []
# 45271                                                   []
# 45272                                                   []
# 45273                                                   []
# 45274                                                   []
# 45275                                                   []
# 45276                                                   []
# 45277                                                   []
# 45278                                                   []
# 45279                                                   []
# 45280                     [got, ta, see, two, three, time]
# 45281                                                   []
# 45282                                                   []
# 45283                                                   []
# 45284                                                   []
# 45285                                                   []
# 45286                                                   []
# 45287                                                   []
# 45288                                                   []
# 45289                                            [strange]
# 45290             [northern, light, morning, magical, day]
# 45291                                                   []
# 45292                                                   []
# 45293                                       [growing, kid]
# 45294                                                   []
# 45295                                                   []
# 45296                                                   []
# 45297                                                   []
# 45298                                                   []
# 45299                                                   []
# 45300                                                   []
# 45301                                                   []
# 45302                                                   []
# 45303                                                   []
# 45304                                 [sad, comedy, angel]
# 45305                                                   []
# 45306                                                   []
# 45307                                                   []
# 45308                                                   []
# 45309                                                   []
# 45310                                                   []
# 45311              [basement, tape, sigrídur, níelsdóttir]
# 45312                                                   []
# 45313                                                   []
# 45314                                                   []
# 45315                                                   []
# 45316                                                   []
# 45317                                                   []
# 45318                                                   []
# 45319                                                   []
# 45320                                                   []
# 45321                                                   []
# 45322                                                   []
# 45323                                                   []
# 45324                                                   []
# 45325                                                   []
# 45326    [love, make, world, go, round, spin, lot, fast...
# 45327    [art, obsession, anxiety, permeate, dilapidate...
# 45328                                                   []
# 45329                                                   []
# 45330                                                   []
# 45331                           [never, lose, touch, root]
# 45332                                                   []
# 45333                                                   []
# 45334                                                   []
# 45335                    [paybackthe, best, form, revenge]
# 45336                                                   []
# 45337                 [big, city, big, buck, big, trouble]
# 45338                                                   []
# 45339                                 [thanks, invitation]
# 45340                        [truly, different, adventure]
# 45341                                                   []
# 45342                                                   []
# 45343                                                   []
# 45344    [since, fritz, cat, freewheeling, sexy, cartoo...
# 45345                                                   []
# 45346                                                   []
# 45347                                         [final, cut]
# 45348         [100, year, later, lightning, strike, twice]
# 45349                                                   []
# 45350                            [lady, man, lady, killer]
# 45351                                                   []
# 45352                                                   []
# 45353    [frankenstein, created, beautiful, woman, soul...
# 45354                              [holy, reunion, batman]
# 45355                                                   []
# 45356                                                   []
# 45357       [came, investigate, witchcraft, found, terror]
# 45358                         [fun, game, great, outdoors]
# 45359                                                   []
# 45360                                                   []
# 45361                                                   []
# 45362                                                   []
# 45363                         [world, need, shining, hero]
# 45364                    [cried, rape, one, would, listen]
# 45365                                                   []
# 45366      [monstrous, chilling, terror, stalking, living]
# 45367                                                   []
# 45368                               [father, art, trouble]
# 45369                                                   []
# 45370                                                   []
# 45371                                                   []
# 45372                                  [speed, part, game]
# 45373                          [good, hostage, hard, find]
# 45374                                                   []
# 45375                [love, story, last, beyond, lifetime]
# 45376                                                   []
# 45377                                                   []
# 45378                                                   []
# 45379                                                   []
# 45380                             [like, easy, love, hard]
# 45381                                                   []
# 45382                                                   []
# 45383                                                   []
# 45384                        [heat, kill, something, else]
# 45385                                                   []
# 45386                                                   []
# 45387                                                   []
# 45388                                                   []
# 45389                                                   []
# 45390               [thing, stand, butch, serenawill, die]
# 45391                                                   []
# 45392                                                   []
# 45393                                                   []
# 45394                                                   []
# 45395                                          [good, die]
# 45396                                                   []
# 45397                                                   []
# 45398                                                   []
# 45399                                                   []
# 45400                                                   []
# 45401                                                   []
# 45402                                                   []
# 45403                                                   []
# 45404                                                   []
# 45405                                                   []
# 45406                                                   []
# 45407                                                   []
# 45408                                                   []
# 45409                                                   []
# 45410                                                   []
# 45411                                                   []
# 45412                                                   []
# 45413                                                   []
# 45414                                                   []
# 45415                                                   []
# 45416                                                   []
# 45417             [one, kid, fantasy, one, cop, nightmare]
# 45418                                                   []
# 45419                                                   []
# 45420                      [night, fall, adventure, begin]
# 45421                                                   []
# 45422                                                   []
# 45423                [notorius, scandalous, unforgettable]
# 45424                                                   []
# 45425                                                   []
# 45426                                    [going, anywhere]
# 45427                                                   []
# 45428                          [sexy, fearless, fit, kill]
# 45429    [prepared, dealing, prospect, humanity, end, e...
# 45430                                                   []
# 45431                                                   []
# 45432                                                   []
# 45433                                                   []
# 45434                                                   []
# 45435                                                   []
# 45436                                     [action, horror]
# 45437                           [heart, want, heart, want]
# 45438                                 [movie, andre, haze]
# 45439                       [rapturous, beautyfury, beast]
# 45440                                                   []
# 45441                                         [cool, rule]
# 45442                                                   []
# 45443                                                   []
# 45444                                                   []
# 45445                                                   []
# 45446                                                   []
# 45447                                                   []
# 45448                                                   []
# 45449                [celebrate, lumpys, first, halloween]
# 45450                                                   []
# 45451                                                   []
# 45452                                                   []
# 45453                                                   []
# 45454                              [happened, last, night]
# 45455                                                   []
# 45456                                   [meetthe, creeper]
# 45457                                                   []
# 45458    [know, happened, 50, year, blair, witch, project]
# 45459                                                   []
# 45460                                                   []
# 45461                        [rising, falling, man, woman]
# 45462                                                   []
# 45463                                  [deadly, game, wit]
# 45464                                                   []
# 45465                                                   []
# Name: preprocessed_tagline, dtype: object

# %%
df["preprocessed_title"] = df["title"].apply(preprocess_text)
df["title"]

# %%
df["preprocessed_overview"] = df["overview"].apply(preprocess_text)
df["preprocessed_overview"]

# %%
def preprocess_colection(coleccion):
    id_coleccion = -1
    if type(coleccion) != float:
        id_coleccion = re.search("'id' *: *([0-9]+)", coleccion)[1]
    return id_coleccion

df["preprocessed_colection"] = df["belongs_to_collection"].apply(preprocess_colection)
df["preprocessed_colection"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-95143124e82b> in <module>
#       5     return id_coleccion
#       6
# ----> 7 df["preprocessed_colection"] = df["belongs_to_collection"].apply(preprocess_colection)
#       8 df["preprocessed_colection"]
#
# NameError: name 'df' is not defined

# %%
#Fecha dejar a nulo, no eliminar
#Pais / idioma variables categoricas, agrupar en regiones y one hot encoding
#Objetivo es convertir en variables numericas, añadiendo columnas por one hot encoding
